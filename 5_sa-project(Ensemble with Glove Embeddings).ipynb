# %%
# Importing necessary libraries
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Embedding, LSTM, GRU, Dense, Dropout, Input, Bidirectional, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

# Load dataset
file_path = '/kaggle/input/twitter-us-airline/Twitter_US_Airline/Tweets.csv'  # Replace with your dataset path
data = pd.read_csv(file_path)

# Data preprocessing
data = data[['text', 'airline_sentiment']].dropna()  # Keep relevant columns and remove nulls
label_encoder = LabelEncoder()
data['sentiment_encoded'] = label_encoder.fit_transform(data['airline_sentiment'])  # Encode sentiments

# Tokenization and padding
max_words = 20000
max_len = 100
tokenizer = Tokenizer(num_words=max_words, oov_token='<OOV>')
tokenizer.fit_on_texts(data['text'])
sequences = tokenizer.texts_to_sequences(data['text'])
padded_sequences = pad_sequences(sequences, maxlen=max_len, padding='post')

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    padded_sequences, 
    data['sentiment_encoded'], 
    test_size=0.2, 
    random_state=42
)
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# Load GloVe embeddings
embedding_dim = 100
embedding_index = {}
with open('/kaggle/input/glove-6b-100d/glove.6B.100d.txt', 'r', encoding='utf-8') as f:  # Replace with the GloVe path
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embedding_index[word] = coefs

# Create embedding matrix
word_index = tokenizer.word_index
num_words = min(max_words, len(word_index) + 1)
embedding_matrix = np.zeros((num_words, embedding_dim))
for word, i in word_index.items():
    if i < max_words:
        embedding_vector = embedding_index.get(word)
        if embedding_vector is not None:
            embedding_matrix[i] = embedding_vector

# Define the Ensembling Model
inputs = Input(shape=(max_len,))

# Embedding Layer with GloVe
embedding = Embedding(input_dim=num_words, 
                      output_dim=embedding_dim, 
                      weights=[embedding_matrix], 
                      input_length=max_len, 
                      trainable=False)(inputs)

# LSTM Branch
lstm_branch = LSTM(128, return_sequences=True)(embedding)
lstm_branch = LSTM(64)(lstm_branch)

# BiLSTM Branch
bilstm_branch = Bidirectional(LSTM(128, return_sequences=True))(embedding)
bilstm_branch = LSTM(64)(bilstm_branch)

# GRU Branch
gru_branch = GRU(128, return_sequences=True)(embedding)
gru_branch = GRU(64)(gru_branch)

# Concatenate all branches
concatenated = Concatenate()([lstm_branch, bilstm_branch, gru_branch])

# Dense Layers
dense1 = Dense(128, activation='relu')(concatenated)
dropout1 = Dropout(0.5)(dense1)
dense2 = Dense(64, activation='relu')(dropout1)
dropout2 = Dropout(0.5)(dense2)

# Output Layer
outputs = Dense(3, activation='softmax')(dropout2)

# Build the Model
model = Model(inputs=inputs, outputs=outputs)

# Compile the Model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

# Model Summary
model.summary()

# Callbacks for training
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=1)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)

# Train the Model
history = model.fit(
    X_train, y_train,
    epochs=30,   # Increase if needed
    batch_size=32,
    validation_split=0.2,
    callbacks=[early_stopping, lr_scheduler],
    verbose=1
)

# Evaluate the Model
loss, accuracy = model.evaluate(X_test, y_test, verbose=1)
print(f'Test Accuracy: {accuracy:.2f}')

# Save the Model
model.save('ensembled_lstm_bilstm_gru_glove.h5')

# Visualize Training Performance
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Metrics')
plt.xlabel('Epochs')
plt.ylabel('Accuracy / Loss')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_5             │ (None, 100)            │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ embedding_5 (Embedding)   │ (None, 100, 100)       │      1,577,000 │ input_layer_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lstm_4 (LSTM)             │ (None, 100, 128)       │        117,248 │ embedding_5[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bidirectional             │ (None, 100, 256)       │        234,496 │ embedding_5[0][0]      │
# │ (Bidirectional)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ gru_1 (GRU)               │ (None, 100, 128)       │         88,320 │ embedding_5[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lstm_5 (LSTM)             │ (None, 64)             │         49,408 │ lstm_4[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lstm_7 (LSTM)             │ (None, 64)             │         82,176 │ bidirectional[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ gru_2 (GRU)               │ (None, 64)             │         37,248 │ gru_1[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 192)            │              0 │ lstm_5[0][0],          │
# │                           │                        │                │ lstm_7[0][0],          │
# │                           │                        │                │ gru_2[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_5 (Dense)           │ (None, 128)            │         24,704 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_5 (Dropout)       │ (None, 128)            │              0 │ dense_5[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_6 (Dense)           │ (None, 64)             │          8,256 │ dropout_5[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_6 (Dropout)       │ (None, 64)             │              0 │ dense_6[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_7 (Dense)           │ (None, 3)              │            195 │ dropout_6[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 2,219,051 (8.47 MB)
#  Trainable params: 642,051 (2.45 MB)
#  Non-trainable params: 1,577,000 (6.02 MB)
# Epoch 1/30
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 19s 48ms/step - accuracy: 0.5954 - loss: 0.9900 - val_accuracy: 0.6586 - val_loss: 0.7819 - learning_rate: 1.0000e-04
# Epoch 2/30
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 13s 46ms/step - accuracy: 0.6832 - loss: 0.7777 - val_accuracy: 0.6944 - val_loss: 0.7146 - learning_rate: 1.0000e-04
# Epoch 3/30
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 13s 46ms/step - accuracy: 0.7023 - loss: 0.7158 - val_accuracy: 0.7213 - val_loss: 0.6754 - learning_rate: 1.0000e-04
# Epoch 4/30
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 13s 46ms/step - accuracy: 0.7250 - loss: 0.6873 - val_accuracy: 0.7392 - val_loss: 0.6463 - learning_rate: 1.0000e-04
# Epoch 5/30
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 13s 46ms/step - accuracy: 0.7444 - loss: 0.6487 - val_accuracy: 0.7495 - val_loss: 0.6381 - learning_rate: 1.0000e-04
# Epoch 6/30
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 13s 46ms/step - accuracy: 0.7546 - loss: 0.6252 - val_accuracy: 0.7426 - val_loss: 0.6130 - learning_rate: 1.0000e-04
# Epoch 7/30
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 13s 46ms/step - accuracy: 0.7527 - loss: 0.6215 - val_accuracy: 0.7610 - val_loss: 0.5989 - learning_rate: 1.0000e-04
# Epoch 8/30
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 13s 46ms/step - accuracy: 0.7466 - loss: 0.6257 - val_accuracy: 0.7422 - val_loss: 0.6472 - learning_rate: 1.0000e-04
# Epoch 9/30
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 13s 46ms/step - accuracy: 0.7709 - loss: 0.5943 - val_accuracy: 0.7520 - val_loss: 0.6244 - learning_rate: 1.0000e-04
# Epoch 10/30
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - accuracy: 0.7754 - loss: 0.5833 - val_accuracy: 0.7606 - val_loss: 0.5878 - learning_rate: 1.0000e-04
# Epoch 11/30
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 13s 46ms/step - accuracy: 0.7789 - loss: 0.5732 - val_accuracy: 0.7648 - val_loss: 0.5841 - learning_rate: 1.0000e-04
# Epoch 12/30
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - accuracy: 0.7749 - loss: 0.5791 - val_accuracy: 0.7806 - val_loss: 0.5568 - learning_rate: 1.0000e-04
# Epoch 13/30
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 13s 46ms/step - accuracy: 0.7828 - loss: 0.5614 - val_accuracy: 0.7725 - val_loss: 0.5633 - learning_rate: 1.0000e-04
# Epoch 14/30
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 13s 46ms/step - accuracy: 0.7867 - loss: 0.5572 - val_accuracy: 0.7725 - val_loss: 0.5627 - learning_rate: 1.0000e-04
# Epoch 15/30
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7923 - loss: 0.5202
# Epoch 15: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - accuracy: 0.7923 - loss: 0.5203 - val_accuracy: 0.7764 - val_loss: 0.5710 - learning_rate: 1.0000e-04
# Epoch 16/30
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 13s 46ms/step - accuracy: 0.8031 - loss: 0.5037 - val_accuracy: 0.7836 - val_loss: 0.5445 - learning_rate: 5.0000e-05
# Epoch 17/30
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 13s 46ms/step - accuracy: 0.7971 - loss: 0.5123 - val_accuracy: 0.7909 - val_loss: 0.5419 - learning_rate: 5.0000e-05
# Epoch 18/30
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 13s 46ms/step - accuracy: 0.8033 - loss: 0.5078 - val_accuracy: 0.7729 - val_loss: 0.5759 - learning_rate: 5.0000e-05
# Epoch 19/30
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - accuracy: 0.8125 - loss: 0.4894 - val_accuracy: 0.7909 - val_loss: 0.5480 - learning_rate: 5.0000e-05
# Epoch 20/30
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 13s 46ms/step - accuracy: 0.8123 - loss: 0.4962 - val_accuracy: 0.7849 - val_loss: 0.5396 - learning_rate: 5.0000e-05
# Epoch 21/30
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 13s 46ms/step - accuracy: 0.8128 - loss: 0.4880 - val_accuracy: 0.7913 - val_loss: 0.5401 - learning_rate: 5.0000e-05
# Epoch 22/30
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 13s 46ms/step - accuracy: 0.8178 - loss: 0.4786 - val_accuracy: 0.7956 - val_loss: 0.5559 - learning_rate: 5.0000e-05
# Epoch 23/30
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8255 - loss: 0.4593
# Epoch 23: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 13s 46ms/step - accuracy: 0.8254 - loss: 0.4594 - val_accuracy: 0.7883 - val_loss: 0.5509 - learning_rate: 5.0000e-05
# Epoch 24/30
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - accuracy: 0.8336 - loss: 0.4550 - val_accuracy: 0.7930 - val_loss: 0.5443 - learning_rate: 2.5000e-05
# Epoch 25/30
# 293/293 ━━━━━━━━━━━━━━━━━━━━ 13s 46ms/step - accuracy: 0.8321 - loss: 0.4407 - val_accuracy: 0.7900 - val_loss: 0.5406 - learning_rate: 2.5000e-05
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 20.
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.7825 - loss: 0.5126
# Test Accuracy: 0.79
